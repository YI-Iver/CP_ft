# %%
import cv2
import numpy as np
import pandas as pd
import os
from sklearn import utils
from tqdm.notebook import tqdm
import matplotlib as plt
import matplotlib.pyplot as matplot
# %matplotlib inline

# %%
data = np.genfromtxt('test3.csv', skip_header = 1, delimiter=',', dtype=float, encoding='UTF-8')
data = np.delete(data,0)
print(data)
# Out:
# [-38. -41. -49. ...  34.  31.  33.]

# %%
#data2 = np.reshape(data,(189,252))
data2 = np.reshape(data,(189,252))

# %%
print(data2)
# Out:
# [[ -38.  -41.  -49. ...   62.   49.   55.]
#  [ -40.  -47.  -64. ...   63.   55.   63.]
#  [ -50.  -78. -100. ...   60.   57.   53.]
#  ...
#  [  29.   29.   29. ...   33.   33.   36.]
#  [  28.   32.   32. ...   36.   32.   37.]
#  [  28.   29.   27. ...   34.   31.   33.]]

# %%
matplot.imshow(data2,cmap='Greys',interpolation='None')
