# %%
import cv2
import numpy as np
import pandas as pd
import os
from sklearn import utils
from tqdm.notebook import tqdm
import matplotlib as plt
import matplotlib.pyplot as matplot
# %matplotlib inline

# %%
data = np.genfromtxt('single_test_20220529.csv', skip_header = 1, delimiter=',', dtype=float, encoding='UTF-8')
data = np.delete(data,0)
print(data)
# Out:
# [121. 126. 127. ... 117. 120. 118.]

# %%
#data2 = np.reshape(data,(189,252))
data2 = np.reshape(data,(95,126,3))
#data2 = data2 - 128

# %%
print(data2)
# Out:
# [[[ 121.  126.  127.]
#   [ 124. -127. -126.]
#   [ 122.  127. -128.]
#   ...
#   [ -67.  -69.  -70.]
#   [ -69.  -71.  -72.]
#   [ -71.  -73.  -74.]]
#
#  [[ 123. -128. -128.]
#   [ 126. -125. -124.]
#   [ 123. -128. -127.]
#   ...
#   [ -66.  -68.  -69.]
#   [ -68.  -71.  -72.]
#   [ -72.  -74.  -75.]]
#
#  [[ 125. -126. -125.]
#   [ 124. -127. -126.]
#   [ 124. -127. -126.]
#   ...
#   [ -67.  -69.  -70.]
#   [ -70.  -72.  -73.]
#   [ -73.  -75.  -76.]]
#
#  ...
#
#  [[  55.   53.   53.]
#   [  58.   56.   56.]
#   [  58.   56.   56.]
#   ...
#   [ 107.  110.  108.]
#   [ 111.  114.  112.]
#   [ 117.  118.  116.]]
#
#  [[  54.   52.   52.]
#   [  60.   59.   59.]
#   [  59.   57.   57.]
#   ...
#   [ 109.  112.  110.]
#   [ 115.  118.  116.]
#   [ 116.  119.  117.]]
#
#  [[  55.   53.   53.]
#   [  55.   53.   53.]
#   [  58.   56.   55.]
#   ...
#   [ 110.  113.  111.]
#   [ 113.  116.  114.]
#   [ 117.  120.  118.]]]

# %%
matplot.imshow(data2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
