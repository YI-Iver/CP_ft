# %%
import cv2
import numpy as np
import pandas as pd
import os
from sklearn import utils
from tqdm.notebook import tqdm
import matplotlib as plt
import matplotlib.pyplot as matplot
# %matplotlib inline

# %%
data = np.genfromtxt('temp_20220531.csv', delimiter=',', dtype=int, encoding='UTF-8')
data = np.delete(data,0)
print(data)
# Out:
# [121 127 126 ... 114 117 115]

# %%
data2 = np.reshape(data,(125,223,3))

# %%
print(type(data2))

print(np.shape(data2))

print(data2)

data2 = np.array(data2,dtype=np.uint8)

cv2.imshow("image1",data2)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <class 'numpy.ndarray'>
# (125, 223, 3)
# [[[121 127 126]
#   [121 127 126]
#   [125 130 131]
#   ...
#   [185 183 182]
#   [184 182 181]
#   [184 182 181]]
#
#  [[122 127 128]
#   [124 129 130]
#   [123 128 129]
#   ...
#   [185 184 182]
#   [184 182 181]
#   [184 182 181]]
#
#  [[122 126 128]
#   [123 128 129]
#   [125 130 131]
#   ...
#   [186 184 183]
#   [184 182 181]
#   [183 181 180]]
#
#  ...
#
#  [[ 55  53  53]
#   [ 56  54  54]
#   [ 56  54  54]
#   ...
#   [114 117 115]
#   [117 120 118]
#   [115 118 116]]
#
#  [[ 57  55  55]
#   [ 56  54  54]
#   [ 55  53  53]
#   ...
#   [113 116 114]
#   [116 119 117]
#   [116 119 117]]
#
#  [[ 55  53  53]
#   [ 54  52  52]
#   [ 55  53  53]
#   ...
#   [113 116 114]
#   [114 117 115]
#   [114 117 115]]]

# %%
matplot.imshow(data2)
